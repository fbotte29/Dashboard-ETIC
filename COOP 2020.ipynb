# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure



df = pd.read_csv("temperatures_eticok_V2.csv", parse_dates=['Time'], index_col="Time")
ax = df.plot()
ax.set_ylabel("Température en °C", fontsize=16)
ax.set_xlabel("Date", fontsize=16)


#df = pd.read_csv("temperatures_eticok.csv", parse_dates=['Time'], index_col="Time")


plt.title('Temperatures COOP 2020', fontsize=30)
plt.gcf().set_size_inches(20, 10)

plt.axhline(y = 30, color = 'r', linestyle = 'dashed', label = 'seuil limite 30')
plt.axhline(y = 28, color = 'b', linestyle = 'dashed', label = "seuil inconfort 28")
# plotting the legend
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper center')

#plt.tight_layout()
plt.show()
