# %%
import datetime
import requests as re
import pandas as pd
import json
import csv
import time
import datetime
from datetime import date
#d = datetime.date(2020,1,4)


today = date.today()
print(today)
d = datetime.date.today()
unixtime = time.mktime(d.timetuple())
print(unixtime)

#api2 = ("http://api.openweathermap.org/data/2.5/onecall/timemachine?lat=45.187604404569896&lon=5.704903862324499&units=metric&lang=fr&dt=1618992000&APPID=053c09565de3a966efa5b8d39b2969d9")

api2 = "http://api.openweathermap.org/data/2.5/onecall/timemachine?"
params = {
       'lat': '45.187604404569896',
       'lon': '5.704903862324499',
       'type': 'hour',
       'units': 'metric',
       'dt':  str(int(unixtime)),
       'lang': 'fr',
       'appid': '053c09565de3a966efa5b8d39b2969d9'
}

response = re.request("GET", api2, params=params)
print(response.text)
# Out:
# 2021-04-26
# 1619388000.0
# {"lat":45.1876,"lon":5.7049,"timezone":"Europe/Paris","timezone_offset":7200,"current":{"dt":1619388000,"sunrise":1619411612,"sunset":1619462166,"temp":13.26,"feels_like":11.25,"pressure":1013,"humidity":54,"dew_point":4.16,"uvi":7.36,"clouds":0,"visibility":10000,"wind_speed":1.03,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},"hourly":[{"dt":1619308800,"temp":10.41,"feels_like":7.21,"pressure":1018,"humidity":54,"dew_point":1.51,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":240,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},{"dt":1619312400,"temp":10.22,"feels_like":7.69,"pressure":1018,"humidity":62,"dew_point":3.27,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},{"dt":1619316000,"temp":9.14,"feels_like":7.16,"pressure":1018,"humidity":81,"dew_point":6.06,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},{"dt":1619319600,"temp":8.73,"feels_like":5.8,"pressure":1017,"humidity":87,"dew_point":6.69,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":80,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},{"dt":1619323200,"temp":8.36,"feels_like":5.35,"pressure":1017,"humidity":87,"dew_point":6.33,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":100,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01n"}]},{"dt":1619326800,"temp":8.13,"feels_like":4.71,"pressure":1017,"humidity":87,"dew_point":6.1,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619330400,"temp":10.48,"feels_like":7.7,"pressure":1017,"humidity":81,"dew_point":7.36,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":90,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619334000,"temp":13.12,"feels_like":9.32,"pressure":1017,"humidity":62,"dew_point":6.01,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619337600,"temp":15.02,"feels_like":11.59,"pressure":1016,"humidity":55,"dew_point":6.06,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619341200,"temp":16.7,"feels_like":13.72,"pressure":1017,"humidity":45,"dew_point":4.72,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619344800,"temp":18.31,"feels_like":15.64,"pressure":1016,"humidity":40,"dew_point":4.49,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":110,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619348400,"temp":19.27,"feels_like":16.77,"pressure":1016,"humidity":35,"dew_point":3.45,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619352000,"temp":20.04,"feels_like":18.05,"pressure":1016,"humidity":40,"dew_point":6.04,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619355600,"temp":20.89,"feels_like":17.94,"pressure":1015,"humidity":35,"dew_point":4.87,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":220,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619359200,"temp":21.04,"feels_like":18.47,"pressure":1014,"humidity":35,"dew_point":5.01,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":250,"weather":[{"id":800,"main":"Clear","description":"ciel dégagé","icon":"01d"}]},{"dt":1619362800,"temp":20.36,"feels_like":17.94,"pressure":1 ...

# %%
response.text 
data_dict = response.json()

# %%
with open("data_file.json", "w") as write_file:
    json.dump(data_dict, write_file)

# %%
print(data_dict['current']['dt'], data_dict['current']['temp'])
# Out:
# 1618963200 7.61

# %%
df1 = pd.json_normalize(data_dict['hourly'])

# %%
df1.dt
# Out:
# 0     1618963200
# 1     1618966800
# 2     1618970400
# 3     1618974000
# 4     1618977600
# 5     1618981200
# 6     1618984800
# 7     1618988400
# 8     1618992000
# 9     1618995600
# 10    1618999200
# 22 2021-04-21 22:00:00   7.57        5.32      1017        93       6.51
# 23 2021-04-21 23:00:00   6.92        4.70      1017        87       4.91
#
#     clouds  visibility  wind_speed  wind_deg  \
# 0        0       10000        1.54       260
# 1       90       10000        1.54         0
# 2       90       10000        2.06       330
# 3        0       10000        2.57        90
# 4        0       10000        3.09        60
# 5        0       10000        5.66        70
# 6        0       10000        1.03         0
# 7        0       10000        2.57        90
# 8       75       10000        1.03         0
# 9       75       10000        1.54       330
# 10      90       10000        1.03         0
# 11      75       10000        0.51         0
# 12      75       10000        1.54       280
# 13      75       10000        1.03         0
# 14       0       10000        2.06       330
# 15      96       10000        2.06       350
# 16      75       10000        3.60       290
# 17      75       10000        2.57        10
# 18      90       10000        2.57       280
# 19      90       10000        1.54        90
# 20      90       10000        2.06        90
# 21      90       10000        1.03       140
# 22      90       10000        2.06        70
# 23      75       10000        1.54        90
#
#                                               weather  rain.1h
# 0   [{'id': 800, 'main': 'Clear', 'description': '...      NaN
# 1   [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 2   [{'id': 500, 'main': 'Rain', 'description': 'l...     0.76
# 3   [{'id': 500, 'main': 'Rain', 'description': 'l...     0.51
# 4   [{'id': 500, 'main': 'Rain', 'description': 'l...     0.51
# 5   [{'id': 800, 'main': 'Clear', 'description': '...      NaN
# 6   [{'id': 800, 'main': 'Clear', 'description': '...      NaN
# 7   [{'id': 800, 'main': 'Clear', 'description': '...      NaN
# 8   [{'id': 803, 'main': 'Clouds', 'description': ...      NaN
# 9   [{'id': 803, 'main': 'Clouds', 'description': ...      NaN
# 10  [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 11  [{'id': 501, 'main': 'Rain', 'description': 'p...     1.02
# 12  [{'id': 500, 'main': 'Rain', 'description': 'l...     0.43
# 13  [{'id': 803, 'main': 'Clouds', 'description': ...      NaN
# 14  [{'id': 800, 'main': 'Clear', 'description': '...      NaN
# 15  [{'id': 500, 'main': 'Rain', 'description': 'l...     0.42
# 16  [{'id': 803, 'main': 'Clouds', 'description': ...      NaN
# 17  [{'id': 803, 'main': 'Clouds', 'description': ...      NaN
# 18  [{'id': 500, 'main': 'Rain', 'description': 'l...     0.26
# 19  [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 20  [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 21  [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 22  [{'id': 804, 'main': 'Clouds', 'description': ...      NaN
# 23  [{'id': 803, 'main': 'Clouds', 'description': ...      NaN

# %%
with open(r"temp_ext.csv", "a") as f:
    df1.to_csv(f, header=f.tell()==0, index = True) #La méthode tell() de l’objet fichier retourne la position actuelle du curseur. Par conséquent, si le fichier est vide ou n’existe pas, f.tell==0 est True, de sorte que header est mis à True ; sinon, header est mis à False.
